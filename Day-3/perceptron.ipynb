# %% [markdown]
# **What is Perceptron?**
# - Perceptron is an algortihm like linear regression used for supervised machine learning. The difference is that it is a building block of deep learning.
#
# ![download.png](attachment:download.png)
# - It is also a mathematical model.
# - also can be called a mathematical function.
# - $z=W_1X_1+W_2X_2+b$
# - IT is passed forward to the activation function.
# - Suppose we have a data of the 1000 students. Consider we have iq, cgpa and their placement.
# |**iq**|cgpa|placement|
# |-|-|-|
# |78|78|1|
# |69|51|0|
# - suppose we are trying to build a model for predicting the placement.
# - When using perceptron, we first train the perceptron.
# - During the training process, we take each student at a time.
# - Thus x1 will be iq and the x2 will be cgpa.
# - first x1=78,x2=78, then we find the value of the weights.
# - consider we have the value w1=1, w2-2 and b=3
# - then for a student(5.1,100) we pass to perceptron
# - $100w_1+3.1w_2+3$
# - = 113.2, this we pass to the activation function and we will get whatever the result but this is just the basic concept of it.

# %% [markdown]
# **Interpretation of preceptron**
# - Weights: effect of the input in the output.
# **Geometric intuition**
# - Same as explained in the logistic regrssion.
# - It classify data in binary thus perceptron is a binary classifier.
# - Perceptron can only classify linear data.
