# %% [markdown]
# ### **HOW TO IMPROVE A NEURAL NETWORK**
# 1. Fine tuning NN hyperparameters
# 2. By solving problems
#     - Vanishing
#     - not enough data
#     - slow training
#     - overfitting

# %% [markdown]
# **Fine tuning hyperparameters**
# __________________________
# **Learning rate**:
# - increasing the learning rate as you go further in the layers as the epochs increases
# -------------------
# **Optimizer**\
# **Batch size**
# - smaller batch size give better result but faster
# ---------------------------
# **Activation function**\
# **No of hidden layers**
# - multi hidden layers with fewer neurons performs better because of the reason that deep learning using the method called representation learning. The first layers caputures the primitive features. Then the deep leyers are resposible for creating the face from primitive features.
# - Stop hidden layers if the model starst overfitting.
# -----------
# **Epochs**
# - if the result become stable then stop the epochs
# - there is the mechanism called early stopping to handle this problem
# ------------------
# **No of neruon per layers**
# - keep the neurons according to the input dim in the input layer
# - keep the ouput neruon as much as the ouput are required
# - keep decreasing the hidden neurons in the hidden layers
# - although keeping the same can be done
# - the nodes must be sufficient
# - the layers should be created in the way that the hidden layers do not lose the features since the further layers cannot recover the hidden layers
