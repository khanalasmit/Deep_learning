# %% [markdown]
# ### **WHY DO WE NEED BACK PROPAGATION?**
# ____________________________________________
# - Loss function is the function of all the trainable parameters
# - Thus we tune the parameters to minimize the loss function.
# -
