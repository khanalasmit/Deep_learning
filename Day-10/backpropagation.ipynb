# %% [markdown]
# **Backpropagation**
# - an algorithm for supervised learning or artificial neural network using gradient descent. Given an artificial neural network and error function, the method calculates the gradient of the error function with respect to the neural network's weights.

# %% [markdown]
# more on the copy

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.DataFrame([[8,8,4],[7,9,5],[6,10,6],[5,12,7]],columns=['cgpa','profile_score','cgpa'])

# %%
df
# Out:
#    cgpa  profile_score  cgpa
# 0     8              8     4
# 1     7              9     5
# 2     6             10     6
# 3     5             12     7

# %%
def initialize_parameters(layer_dims):
    np.random.seed(3)
    parameters={}
    L=len(layer_dims)
    for l in range(1,L):
        parameters['W'+str(l)]=np.ones((layer_dims[l-1],layer_dims[l]))*0.1
        parameters['b'+str(l)]=np.zeros((layer_dims[l-1],1))
    return parameters

# %%
initialize_parameters([2,2,1])
# Out:
# {'W1': array([[0.1, 0.1],
#         [0.1, 0.1]]),
#  'b1': array([[0.],
#         [0.]]),
#  'W2': array([[0.1],
#         [0.1]]),
#  'b2': array([[0.],
#         [0.]])}

# %%
def linear_forward(A_prev,W,b):
    Z=np.dot(W.T,A_prev)+b
    return Z

# %%
#function for the forward propagation
def L_layer_forward(X,parameters):
    A=X
    L=len(parameters)//2 #number of layers in the neural network
    for l in range(1,L+1):
        A_prev=A
        Wl=parameters['W'+str(l)]
        bl=parameters['b'+str(l)]
        
        A=linear_forward(A_prev,Wl,bl)
    return A,A_prev

# %%
def update_parameters(parameters,y,y_hat,A1,X):
    parameters['W2'][0][0]=parameters['W2'][0][0]+0.01*2*(y-y_hat)*A1[0][0]
    parameters['W2'][0][0]=parameters['W2'][0][0]+0.01*2*(y-y_hat)*A1[1][0]
    parameters['W2'][0][0]=parameters['W2'][0][0]+0.01*2*(y-y_hat)*A1[1][0]
