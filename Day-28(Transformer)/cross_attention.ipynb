# %% [markdown]
# In the decoder architecture we have the multi head attention after masked multi head attention.
#
# But the arrows here we have are also comming from the endcode that is the cross attention.
#
# **What is cross attnetion?**
# - Cross attention is a mechanism used in transformer architectures particularly in tasks invloding sequence to sequence data like translation or summarization. It allows a model to focus on different parts of an input sequence when generating an output sequence.
#
# Translation depends upon what has the decoder generated till now and the input sentence.
#
# For the first part the contextual embedding from the masked self attention is enough
#
# Fro the second part, we need the relationship of the output sequence with the input sequence.
#
# ![image.png](attachment:image.png)
#
# The cross attention finds the similarity between two sequences. The cross attention is conceptually similar to self attention. The difference is
# 1. Input
# 2. The processsing
# 3. The output
# -------------------
# 1. Input
#     - ![image-2.png](attachment:image-2.png)
# 2. The processing
#     - ![image-3.png](attachment:image-3.png)
#     - The key and value are the english word.
#     - For the hindi word we have the query value corresponding to each hindi word.
#     - ![image-4.png](attachment:image-4.png)
# 3. The output
#     - ![image-5.png](attachment:image-5.png)
