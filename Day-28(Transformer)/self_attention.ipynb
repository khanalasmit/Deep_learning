# %% [markdown]
# ### **Self Attention**
#
# ----------
#
# **Word Embedding**
#
# Capable of caputring semantic meaning
# - It does so by converting a word in n dimension vector
# - The words similar will have the similar value of the embedding vectors.
# - The embedding is done on the basis of the similarity to the ceratin factors.
#
# -------------------------
#
# **The problem of "Average Meaning"**
# 1. The word embedding captures a average meaning. It caputres the meaning based on what context it is in. The weitage is increased based on the appearance in the certain context.
# 2. The data influence the meaning
# 3. The word embeddings are created ones and then used multiple times this means if trained with a certain context it will influence bad in the next context.
#
# ----------------------
#
# **First Principle Approach**
# 1. money bank grows
# 2. river bank flows
#
# Using word embedding causes the problem
#
# BUt what if write,
# 1. bank=0.3 money+0.7 bank+ 0.1 grows
# 2. bank=0.5 river+0.4 bank+0.1 flows
# 3. grows=0.1 money+0.2 bank+0.7 grows
#
# What advantage there is that the bank will have the different meaning
#
# What we can do here is converts each words in word embedding
# e_{money}=0.7 e_{money}+ 0.2 e_{bank}+ 0.1e_{grows}
#
# Each number means that new embedding of the money 0.7 made of old embedding of money
#
# They are representing the similariy between the words.
#
# $e_{bank}^{new}=[e_{bank}.e_{money}^T]e_{money}+[e_{bank}.e_{bank}^T]e_{bank}+[e_{bank}.e_{grows}^{T}]e_{grows}$
#
# Then the normlaization is done on the above obtained result
#
# This means that we will gain the interpretation about the probablity of the similarity
#
# For the normalization we use the softmax funcition
#
# - ![image.png](attachment:image.png)
#
# - The embeddings can be generated in parallel
# - ![image-2.png](attachment:image-2.png)
# - The parallel infromation will lose the sequence.
#
# ---------------------
#
# - Here are no learning parameters
# - It is the general contextual embedding. It could be a problem such as in case of translating word "piece of cake". Thus we may need task specific contextual embedding.
# - thus we need to introduce some weights and biases
#
# ---------------------------
#
# In the above pictue, we see that the money words appers in three locations. The green box queries the pink embeddings for similarity. We use the each embedding vector as:
# - key
# - value
# - query
#
# The problem with the approach is : that a same vector is peforming the task
#
# We can do the separation of the concerns. That is sepearting into three vectors.
# - q_{}
# - k
# - v
#
# How are we doing this?
# - we are deciding what to put in the vector through data.
# - how to decide the values. we decide with random value and find the optimal data through training.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### **Why self attention called self?**

# %% [markdown]
# - why is the attention there?
#     -
