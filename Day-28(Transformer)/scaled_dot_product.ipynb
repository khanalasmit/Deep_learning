# %% [markdown]
# ### **Review**
# ----------------------
# - $Attention(Q,K,V) = softmax(QK^{T})V$
# - we will scaled the above attention
# - Thus we are going with the scaled dot product attention.
