# %% [markdown]
# **Perceptron with sigmoid**
# - The activation function in the perceptron is the sigmoid funtion and the loss function used is the log loss function.
# - To perdict the output.
# - The ouput will be the probablity rather than being 0 and 1.

# %% [markdown]
# - To make the non linear decision boundsary we can combine multiple linear bouandaries and then do the smoothening.
# - It is done by taking the multuiple perceptron.
# - It is the abstract idea of the MLP.

# %% [markdown]
# - Here we can use the weight to impact the result of one perceptron more than the other one.
# - ![image.png](attachment:image.png)

# %% [markdown]
# **Adding nodes in output node**
# - ![image.png](attachment:image.png)

# %% [markdown]
# **Deep neural network**
# - can be made capable to caputure each patterns with the use of the deep hidden layers.
