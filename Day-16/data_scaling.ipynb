# %% [markdown]
# ### **problem**
# - if the scale of the input data is not uniform  the model takes long time to train or may not even train(oscaillting accuracy at each epochs).
# - This happens because
#     - when the backpropagation is used in the data, the focus will be towards a single weights, thus making the ununiform training
#     - ![image.png](attachment:image.png)
# - for the unscaled data we do the scaling or standardize
