# %% [markdown]
# ### **INTRODUCTION**

# %% [markdown]
# - we are optimizing the weights and biases to minimize the loss

# %% [markdown]
# **Types of optimizers**
# - Batch GD
# - Stochatic GD
# - mini batch GD

# %% [markdown]
# **Challenges**
# - Learning rate: finding the optimal value
# - learning rate scheduling(needs to be predetermined)
# - same learning rate for each of the weights and the biases
# - converge to the local minimum rather than the global minima
# - saddel point
