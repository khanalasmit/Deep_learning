# %% [markdown]
# ### **Mathematical Intuition**
# - $W_{la}=W_t-\beta V_{t-1}$
# - $V_t=\beta V_{t-1}+\eta \nabla W_{la}$
# - $W_{t+1}=W_t-V_t$

# %% [markdown]
# - Here we are fist applying momentum then we are applying the gradient for the update
# - ![image.png](attachment:image.png)

# %% [markdown]
# ### **Disadvantage**
# - although it damps the oscillation due to the momentum, it may stuck the to the local minima
# -
